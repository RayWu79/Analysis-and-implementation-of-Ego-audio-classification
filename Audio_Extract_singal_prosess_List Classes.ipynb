# %% [markdown]
# ## Audio Signal Extract and Process to String Classes

# %% [markdown]
# ### Libraries

# %%
import os
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn.functional as F
import torch.nn as nn

import warnings
warnings.filterwarnings('ignore')

# Audio processing library for analyzing and extracting features from audio signals
import librosa

# Library for reducing noise from audio signals
import noisereduce as nr

import pickle

# Library for working with video files, including reading and editing
from moviepy.editor import VideoFileClip

from numpy import isfinite 

import math

# %% [markdown]
# ### Require Data Loading and Processing

# %%
print(os.getcwd())
# Out:
# /home/chijuiwu/snap/snapd-desktop-integration/83/Desktop/CapstoneProject

# %%
# Path of training excal which including video name, labels, duration, etc.
Train_excal_path = '/home/chijuiwu/snap/snapd-desktop-integration/83/Desktop/CapstoneProject/CharadesEgoInfo/CharadesEgo_v1_test_only1st.csv'

df = pd.read_csv(Train_excal_path)

# %%
print(df)
# Out:
#            id subject         scene  quality  relevance verified  \
# 0    W1XD0EGO    I2IV       Bedroom      7.0        7.0      Yes
# 1    NU9BQEGO    V258        Pantry      5.0        7.0      Yes
# 2    EY2W7EGO    VQ30       Bedroom      4.0        6.0      Yes
# 3    X28BIEGO    VT5W   Dining room      6.0        6.0      Yes
# 4    DVSVQEGO    7CY9       Kitchen      7.0        7.0      Yes
# ..        ...     ...           ...      ...        ...      ...
# 841  39JUOEGO    A66R        Pantry      7.0        7.0      Yes
# 842  HKKESEGO    H8N1         Other      5.0        5.0      Yes
# 843  F829EEGO    15B9        Pantry      5.0        5.0      Yes
# 844  ZLYISEGO    Z241   Living room      6.0        6.0      Yes
# 845  7HU7REGO    Z241  Laundry room      6.0        7.0      Yes
#
#                                                 script  \
# 0    Person is holding picture, then puts picture o...
# 1    A person is tidying up the groceries in a pant...
# 2    Person enters the bedroom and stands next to t...
# 3    A person is sitting in a chair working on fixi...
# 4    A person puts a pot on the stove. The person p...
# ..                                                 ...
# 841  A person is smiling as they walk into a pantry...
# 842  A person takes a pair of shoes from the shelf....
# 843  The person opens the pantry and pulls out food...
# 844  A person is eating a sandwich, then cleaning w...
# 845  A person runs into the laundry room grasping a...
#
#                                                objects descriptions  \
# 0    bed;hands;paper/notebook;picture;pillow;sofa/c...          NaN
# 1                              broom;cabinet;door;wall          NaN
# 2             bottle;chair;dish;door;glass;light;table          NaN
# 3                              chair;laptop;shoe;table          NaN
# 4                            dish;food;phone;pot;stove          NaN
# ..                                                 ...          ...
# 841  box;broom;closet/cabinet;floor;food;groceries;...          NaN
# 842                                         shelf;shoe          NaN
# 843  a counter;box;cabinet;dish;door;food;pillow;sh...          NaN
# 844    chair;doorway;food;laptop;sandwich;towel;window          NaN
# 845  broom;clothes;door;fan;mirror;nick nack shelf;...          NaN
#
#                                                actions  length egocentric  \
# 0    c115 0.00 21.70;c116 13.10 22.50;c123 0.00 22....   29.54        Yes
# 1    c098 0.60 23.88;c113 1.60 21.20;c112 16.80 21....   27.83        Yes
# 2    c110 24.20 30.75;c059 12.00 30.75;c109 29.70 3...   33.29        Yes
# 3    c051 0.00 31.25;c046 27.90 31.25;c053 0.00 31....   30.92        Yes
# 4    c152 15.00 22.70;c018 20.30 28.10;c016 24.10 3...   30.08        Yes
# ..                                                 ...     ...        ...
# 841  c149 0.90 6.90;c061 14.70 24.75;c099 2.20 7.90...   24.50        Yes
# 842  c056 3.80 9.75;c053 4.10 9.75;c082 5.10 9.75;c...   18.00        Yes
# 843  c063 5.10 13.60;c008 4.60 10.70;c062 14.80 22....   41.42        Yes
# 844  c097 30.90 31.17;c065 2.70 13.90;c156 2.80 13....   34.46        Yes
# 845  c102 21.90 29.75;c100 17.60 23.40;c154 27.40 2...   37.21        Yes
#
#     charades_video
# 0            LNEAG
# 1              NaN
# 2            8BNUT
# 3            0J1AQ
# 4            K1M15
# ..             ...
# 841            NaN
# 842          B6LRC
# 843            NaN
# 844          MFOVZ
# 845          B8PQL
#
# [846 rows x 13 columns]

# %%
# Select only 'id' and 'actions' columns
selected_data = df[['id', 'actions']]

# Print the selected data
print(selected_data)
# Out:
#            id                                            actions
# 0    W1XD0EGO  c115 0.00 21.70;c116 13.10 22.50;c123 0.00 22....
# 1    NU9BQEGO  c098 0.60 23.88;c113 1.60 21.20;c112 16.80 21....
# 2    EY2W7EGO  c110 24.20 30.75;c059 12.00 30.75;c109 29.70 3...
# 3    X28BIEGO  c051 0.00 31.25;c046 27.90 31.25;c053 0.00 31....
# 4    DVSVQEGO  c152 15.00 22.70;c018 20.30 28.10;c016 24.10 3...
# ..        ...                                                ...
# 841  39JUOEGO  c149 0.90 6.90;c061 14.70 24.75;c099 2.20 7.90...
# 842  HKKESEGO  c056 3.80 9.75;c053 4.10 9.75;c082 5.10 9.75;c...
# 843  F829EEGO  c063 5.10 13.60;c008 4.60 10.70;c062 14.80 22....
# 844  ZLYISEGO  c097 30.90 31.17;c065 2.70 13.90;c156 2.80 13....
# 845  7HU7REGO  c102 21.90 29.75;c100 17.60 23.40;c154 27.40 2...
#
# [846 rows x 2 columns]

# %%
# Extract all unique action codes using regex
action_pattern = r'c\d{3}'
unique_actions = set()

unique_actions_with_no_action = set(['no_action'])  # Initialize set with 'no_action' for NaN cases

for actions in df['actions']:
    if pd.isna(actions):
        continue  # 'no_action' already added, continue without finding regex
    matches = re.findall(action_pattern, str(actions))
    unique_actions_with_no_action.update(matches)

print(unique_actions_with_no_action)
# Out:
# {'c117', 'c022', 'c149', 'c002', 'c143', 'c039', 'c127', 'c009', 'c056', 'c045', 'c047', 'c090', 'c050', 'c088', 'c125', 'c130', 'c032', 'c079', 'c028', 'c055', 'c000', 'c145', 'c021', 'c057', 'c067', 'c144', 'c071', 'c007', 'c156', 'c118', 'c122', 'c104', 'c065', 'c141', 'c015', 'c054', 'c097', 'c095', 'c078', 'c151', 'c083', 'c063', 'c116', 'c073', 'c034', 'c111', 'c112', 'c029', 'c148', 'c107', 'c030', 'c006', 'c037', 'c153', 'c060', 'c025', 'c142', 'c110', 'c058', 'c066', 'c109', 'c005', 'c042', 'c100', 'c081', 'c113', 'c135', 'c114', 'c126', 'c020', 'c001', 'c018', 'c076', 'c140', 'c138', 'c137', 'c027', 'c004', 'c121', 'c105', 'c108', 'c064', 'c011', 'c115', 'c129', 'c070', 'c150', 'c085', 'c084', 'c080', 'c023', 'c012', 'c154', 'c016', 'c044', 'c136', 'c123', 'c128', 'c053', 'no_action', 'c059', 'c046', 'c062', 'c061', 'c146', 'c048', 'c155', 'c120', 'c052', 'c077', 'c014', 'c103', 'c134', 'c139', 'c087', 'c101', 'c072', 'c019', 'c074', 'c119', 'c040', 'c068', 'c147', 'c098', 'c102', 'c131', 'c033', 'c152', 'c075', 'c092', 'c089', 'c036', 'c132', 'c086', 'c026', 'c051', 'c099', 'c106', 'c043', 'c093', 'c041', 'c094', 'c038', 'c049', 'c008', 'c035', 'c017', 'c010', 'c082', 'c003', 'c031', 'c069', 'c013', 'c133', 'c124', 'c096', 'c091', 'c024'}

# %%
# Sorting the unique_actions set
sorted_unique_actions = sorted(unique_actions_with_no_action)
print(sorted_unique_actions)
# Out:
# ['c000', 'c001', 'c002', 'c003', 'c004', 'c005', 'c006', 'c007', 'c008', 'c009', 'c010', 'c011', 'c012', 'c013', 'c014', 'c015', 'c016', 'c017', 'c018', 'c019', 'c020', 'c021', 'c022', 'c023', 'c024', 'c025', 'c026', 'c027', 'c028', 'c029', 'c030', 'c031', 'c032', 'c033', 'c034', 'c035', 'c036', 'c037', 'c038', 'c039', 'c040', 'c041', 'c042', 'c043', 'c044', 'c045', 'c046', 'c047', 'c048', 'c049', 'c050', 'c051', 'c052', 'c053', 'c054', 'c055', 'c056', 'c057', 'c058', 'c059', 'c060', 'c061', 'c062', 'c063', 'c064', 'c065', 'c066', 'c067', 'c068', 'c069', 'c070', 'c071', 'c072', 'c073', 'c074', 'c075', 'c076', 'c077', 'c078', 'c079', 'c080', 'c081', 'c082', 'c083', 'c084', 'c085', 'c086', 'c087', 'c088', 'c089', 'c090', 'c091', 'c092', 'c093', 'c094', 'c095', 'c096', 'c097', 'c098', 'c099', 'c100', 'c101', 'c102', 'c103', 'c104', 'c105', 'c106', 'c107', 'c108', 'c109', 'c110', 'c111', 'c112', 'c113', 'c114', 'c115', 'c116', 'c117', 'c118', 'c119', 'c120', 'c121', 'c122', 'c123', 'c124', 'c125', 'c126', 'c127', 'c128', 'c129', 'c130', 'c131', 'c132', 'c133', 'c134', 'c135', 'c136', 'c137', 'c138', 'c139', 'c140', 'c141', 'c142', 'c143', 'c144', 'c145', 'c146', 'c147', 'c148', 'c149', 'c150', 'c151', 'c152', 'c153', 'c154', 'c155', 'c156', 'no_action']

# %%
# Counting the number of sorted unique actions
number_of_actions = len(sorted_unique_actions)
print(number_of_actions)
# Out:
# 158

# %%
# Convert 'id' column to list for video_files
video_files = selected_data['id'].tolist()
print(video_files)
# Out:
# ['W1XD0EGO', 'NU9BQEGO', 'EY2W7EGO', 'X28BIEGO', 'DVSVQEGO', '2UAB5EGO', 'FIDBIEGO', 'P9SOAEGO', 'KOJLPEGO', 'ZDY4KEGO', 'KLI31EGO', 'KHEM0EGO', 'OWPFMEGO', 'PK0LLEGO', '3OHCPEGO', '2MK76EGO', 'GQT75EGO', 'B78XTEGO', '3L274EGO', 'ZBOC2EGO', 'BNCZFEGO', '0FEXMEGO', 'I7BSOEGO', 'CV173EGO', 'RHJ7SEGO', '4VCG4EGO', 'O9PE4EGO', 'GYCTQEGO', 'D6JJ2EGO', 'OZH09EGO', 'W28V1EGO', 'XYHFAEGO', 'GAAOVEGO', '3JKBFEGO', 'RCOHJEGO', 'CANHSEGO', 'V2I7EEGO', 'L5UQJEGO', 'BUITJEGO', 'AOF10EGO', '6XAC5EGO', 'UNB3NEGO', 'J3MN6EGO', 'WVH1DEGO', '2PIAOEGO', '64U9XEGO', 'YCQM7EGO', 'UMY7CEGO', 'R9N7BEGO', 'PHEHKEGO', 'XBHJOEGO', '1GL7YEGO', 'O4A9IEGO', 'GP0I5EGO', '3NJLIEGO', 'LXK5XEGO', '6GETYEGO', 'REMUKEGO', '8JPE1EGO', 'KTHI4EGO', '6D5DHEGO', 'AUQD5EGO', '555W8EGO', '15AKPEGO', 'LS926EGO', '0N16WEGO', 'CBFVTEGO', 'TQINTEGO', 'TXW0EEGO', 'HSLZ2EGO', 'KLIW5EGO', 'SFHKPEGO', '5LWZKEGO', 'QO363EGO', '0HJFXEGO', 'DI2PBEGO', 'LXD11EGO', 'DXASPEGO', 'KRDB3EGO', '14J04EGO', '4QPMTEGO', 'HIX6DEGO', 'F4OV6EGO', 'WJZ2JEGO', 'E64MVEGO', '56JETEGO', 'GJDYYEGO', '0K355EGO', 'IWIMWEGO', '2CTBWEGO', 'J7G5OEGO', '5LLW9EGO', 'VNNHOEGO', '9BUDVEGO', 'OY7H0EGO', 'JN74IEGO', 'TGPDEEGO', 'HYZSVEGO', 'JD6P7EGO', 'O94D3EGO', 'RWCPZEGO', 'AGSUBEGO', 'CWXIHEGO', 'W3UK5EGO', 'YNJH8EGO', 'S5KXXEGO', 'CCHD2EGO', '210Y2EGO', 'EZ9F1EGO', 'S0SJHEGO', 'W4BIMEGO', 'UHXKGEGO', 'MH0D0EGO', '2R805EGO', '9H4IGEGO', '65Y57EGO', 'CJMTEEGO', 'SVT23EGO', '20DK5EGO', 'H62B5EGO', 'CGI9KEGO', 'KX10SEGO', '5ONU5EGO', 'ULDM8EGO', 'N6GSSEGO', 'KFGJBEGO', 'CVCJWEGO', 'I3B0EEGO', 'J11WMEGO', 'G57LZEGO', 'H50ESEGO', '15ERXEGO', 'D3BYGEGO', 'GH7MYEGO', 'UONGWEGO', '1U3DDEGO', 'IFWPQEGO', '1MJZ8EGO', 'O0DH5EGO', 'WVLMYEGO', 'AD078EGO', 'SFSGSEGO', '88T2XEGO', 'JRAUBEGO', 'JBC1PEGO', 'PB28DEGO', 'CDAKFEGO', 'VXTKHEGO', 'H2M4IEGO', 'BLSWFEGO', '5T8VHEGO', 'UBZYVEGO', 'C048GEGO', 'X03D3EGO', 'ISCCFEGO', '78YXTEGO', 'NFVXHEGO', '2CPK8EGO', 'I3O05EGO', 'MCIB5EGO', 'NW4JNEGO', '3Q2ECEGO', 'JVENTEGO', '8ZQLUEGO', 'Y4EJIEGO', '7ZZJ3EGO', 'E3KZQEGO', 'ZZII9EGO', 'FBOELEGO', 'QHZIPEGO', 'J30SUEGO', '6QZMZEGO', 'YV2JTEGO', 'GA6XPEGO', 'FWZN5EGO', 'OKJCOEGO', 'SYXMYEGO', 'BARH8EGO', 'CPPVIEGO', 'MOJKYEGO', 'XJYKXEGO', 'XFQ4QEGO', 'S3RNQEGO', '7XQ7IEGO', 'UH8G0EGO', '8KTAXEGO', '8WMX0EGO', 'WDAIPEGO', '8YNAAEGO', '6Q1XPEGO', 'MJ5HKEGO', 'XDI1BEGO', 'F54CHEGO', 'TWFIGEGO', 'XQ4YQEGO', 'HTWE5EGO', 'UB3X1EGO', '76JV7EGO', 'PINBDEGO', '0WRGREGO', 'ULWGWEGO', 'AW7U4EGO', 'BL96UEGO', 'H24P6EGO', 'FN34IEGO', 'P957FEGO', 'XZ4IYEGO', 'WOS3WEGO', 'L7KMAEGO', 'FLVDYEGO', 'GI4VQEGO', 'PXSWCEGO', 'AF0EFEGO', '8GLK7EGO', 'PNV3HEGO', 'HT52SEGO', 'IVDMVEGO', 'JBRP2EGO', '3T4QOEGO', 'LVTHBEGO', '33SPCEGO', '55N04EGO', '2JE57EGO', '8BQ6KEGO', 'RPAZJEGO', 'OKM8EEGO', 'ZVD8LEGO', '4W56OEGO', 'GDVUHEGO', '7CJAIEGO', 'U3AWBEGO', 'O4RAREGO', 'RJDRZEGO', '7F94VEGO', '7RL6SEGO', 'N7S4ZEGO', 'DUP5TEGO', '1062AEGO', 'CFJCGEGO', 'B34W3EGO', 'FK1PAEGO', 'YVGZQEGO', 'SJX6OEGO', 'VLS7SEGO', '1X8OYEGO', 'MZSX6EGO', 'NBDZZEGO', '7M6V5EGO', 'QII95EGO', 'SLDGPEGO', 'NM2AXEGO', 'F1UJ6EGO', 'D3CTTEGO', '89SD6EGO', '6MX8EEGO', 'N05JHEGO', 'YFS0QEGO', 'X2JTKEGO', 'LK5AEEGO', '95MGMEGO', '7BYREEGO', 'W2N8LEGO', 'V16S0EGO', 'U6677EGO', 'VR7KBEGO', '6GKM0EGO', 'LEOSTEGO', 'F2ERFEGO', 'L434VEGO', 'B2RYSEGO', 'XWKQNEGO', 'SJ4RPEGO', 'TDVNMEGO', '4941FEGO', 'JMEGMEGO', 'PMWUGEGO', '46BIUEGO', 'A8IM0EGO', 'SA1IUEGO', 'B2UZ1EGO', 'XVFWGEGO', '1HDWSEGO', 'AHRQTEGO', 'LNFLPEGO', 'OVX5TEGO', '2VR86EGO', '4OZKJEGO', 'XOHGMEGO', 'S0YCWEGO', '9H55DEGO', 'B2BLLEGO', 'MKC41EGO', 'BGTMZEGO', 'YR9FTEGO', 'CQOGIEGO', 'ZBX48EGO', 'YWE36EGO', 'XWBJ6EGO', 'PZTHIEGO', '1IA7OEGO', 'GZM5XEGO', 'UX2M4EGO', 'DVDNGEGO', 'HY7KQEGO', 'X0WK0EGO', 'LD1W3EGO', '7LCQCEGO', '5W35LEGO', '1OH4FEGO', 'JV5YOEGO', '6JHMXEGO', 'YJLW9EGO', 'N6XYJEGO', 'QL0EAEGO', 'XUT23EGO', 'T9HE0EGO', 'HL3ONEGO', 'Q6504EGO', 'YSD8JEGO', 'ODYYLEGO', 'LGN5HEGO', 'UHAPLEGO', 'NK1TBEGO', 'OMN9JEGO', 'LXGTEEGO', '2S4YXEGO', 'L7Y0VEGO', 'F3PYNEGO', 'D6ZSTEGO', 'AKJ3MEGO', 'QLRBXEGO', 'BL6HLEGO', 'P3BZBEGO', 'OQ ...

# %%
# Create a dictionary from 'id' and 'actions' for annotations
annotations = dict(zip(selected_data['id'], selected_data['actions']))
print(annotations)
# Out:
# {'W1XD0EGO': 'c115 0.00 21.70;c116 13.10 22.50;c123 0.00 22.50;c139 21.40 22.50;c077 11.60 22.50;c085 17.10 22.50;c084 0.00 20.50;c086 14.90 21.70;c152 20.50 22.50;c077 20.30 22.50;c085 23.50 22.50', 'NU9BQEGO': 'c098 0.60 23.88;c113 1.60 21.20;c112 16.80 21.80;c099 22.20 23.88;c006 16.20 22.30;c008 1.10 6.50;c141 0.90 6.70;c102 0.20 4.40;c100 0.40 4.60', 'EY2W7EGO': 'c110 24.20 30.75;c059 12.00 30.75;c109 29.70 30.75;c008 0.00 30.75;c152 31.20 30.75;c097 10.30 30.75;c141 8.70 30.75;c118 16.80 23.70;c108 12.80 25.00;c008 0.00 8.20;c152 27.50 30.75;c097 0.00 11.70;c141 0.00 11.20;c151 6.80 16.30;c110 16.20 24.00;c009 29.30 30.75;c059 10.20 19.00;c109 22.00 27.50;c107 16.70 30.75;c011 12.80 30.75;c104 4.80 11.20;c118 12.50 30.75;c106 24.70 30.75', 'X28BIEGO': 'c051 0.00 31.25;c046 27.90 31.25;c053 0.00 31.25;c048 0.00 31.25;c052 0.00 31.25;c151 0.50 14.50;c054 0.20 8.70;c059 1.40 13.90;c011 0.00 13.60;c154 0.00 11.00', 'DVSVQEGO': 'c152 15.00 22.70;c018 20.30 28.10;c016 24.10 30.71;c152 23.80 30.71;c147 6.70 30.71;c152 14.60 30.00;c119 4.90 11.60;c015 23.60 30.71', '2UAB5EGO': 'c092 24.70 23.17;c107 0.00 23.17;c119 19.60 23.17;c009 19.60 23.17;c109 19.60 23.17;c118 0.00 23.17', 'FIDBIEGO': 'c006 11.00 17.80;c087 21.30 26.80;c152 0.00 33.12;c016 0.00 33.12;c094 15.00 33.12;c015 0.00 13.00;c154 38.50 33.12;c104 33.80 33.12;c149 23.00 33.12', 'P9SOAEGO': 'c099 0.00 23.21;c127 1.20 23.21;c102 0.00 23.21;c100 0.00 23.21;c098 0.00 23.21;c101 25.20 23.21', 'KOJLPEGO': 'c060 0.50 11.25;c154 0.00 7.60;c112 2.30 10.90;c026 0.00 11.25;c114 0.00 11.25;c040 0.00 11.25;c115 0.00 11.25;c097 0.00 11.25', 'ZDY4KEGO': 'c038 14.80 19.20;c013 7.90 18.30;c037 8.20 18.10;c034 14.90 19.80;c151 15.40 20.10;c059 7.50 24.70;c154 0.00 24.70;c011 0.00 23.60;c036 0.00 22.90;c035 0.00 24.40;c152 1.00 7.80;c092 1.60 12.60;c059 7.30 13.10;c033 9.00 19.50', 'KLI31EGO': 'c149 3.80 13.20;c000 0.00 13.10;c141 10.60 16.80;c152 3.30 12.10;c155 2.20 7.60;c113 9.70 16.20;c006 14.10 17.50;c097 10.80 17.50;c008 11.10 17.50;c155 1.20 13.20;c001 6.40 12.60', 'KHEM0EGO': 'c139 23.50 36.90;c072 0.00 13.60;c146 2.30 11.10;c154 7.70 14.40;c070 0.40 13.60;c075 2.70 17.60;c133 0.00 7.70;c070 9.20 21.10;c075 10.40 20.90;c097 19.90 24.50;c134 0.00 10.50;c104 21.30 26.10', 'OWPFMEGO': 'c078 13.20 24.00;c123 0.00 31.96;c076 12.30 25.50;c079 11.40 19.90;c132 19.10 31.96;c151 10.60 16.60;c106 11.90 18.40;c120 7.90 16.40;c119 10.60 16.40;c135 12.30 16.80', 'PK0LLEGO': 'c030 9.90 15.33;c149 7.60 13.90;c152 7.90 13.90;c154 4.50 10.70;c029 14.60 15.33;c027 9.50 14.70;c125 0.00 4.70;c026 10.20 15.33;c032 10.40 15.33', '3OHCPEGO': 'c097 0.00 3.30;c081 13.30 18.60;c104 5.10 9.80;c049 0.00 21.10;c112 0.00 20.50;c105 0.00 20.50;c047 0.00 12.30', '2MK76EGO': 'c021 4.20 17.10;c023 0.00 17.90;c009 20.20 27.80;c023 11.40 20.70;c020 13.30 17.90;c152 16.10 23.60;c022 13.90 18.80;c107 14.50 25.60;c009 25.80 31.00;c106 17.40 32.10;c009 6.00 12.00;c021 1.70 9.70;c106 15.70 25.60', 'GQT75EGO': 'c076 0.00 13.60;c080 9.00 14.70;c078 0.00 11.60;c077 9.30 15.10;c126 8.60 16.00', 'B78XTEGO': 'c106 8.30 19.80;c098 18.10 24.60;c102 20.60 29.29;c107 9.50 17.70;c092 0.00 7.50;c091 6.50 29.29;c100 6.80 29.29', '3L274EGO': 'c072 11.50 15.67;c071 10.40 15.67;c070 20.20 15.67;c000 18.50 15.67;c053 0.00 14.90;c002 16.50 15.67;c124 18.70 15.67;c006 21.40 15.67;c125 21.60 15.67;c054 22.20 15.67;c001 19.50 15.67', 'ZBOC2EGO': 'c156 18.20 22.80;c107 15.90 23.75;c081 5.90 11.40;c061 0.00 9.90;c068 6.40 11.70;c106 15.70 23.40;c110 15.70 21.00;c040 0.00 10.20;c045 5.60 12.00;c042 4.20 11.10', 'BNCZFEGO': 'c033 0.00 12.25;c038 6.40 12.25', '0FEXMEGO': 'c089 8.00 14.88;c084 0.00 2.70;c083 0.00 14.88;c082 0.00 14.88;c154 3.60 10.80;c152 4.50 11.30;c092 5.20 11.30;c088 7.00 12.80;c089 5.50 9.50;c084 4.20 8.30;c089 1.40 7.70;c084 4.60 14.20', 'I7BSOEGO': 'c086 0.00 15.40;c088 0.00 21.40;c084 8.70 17.90;c083 0.00 12.80;c097 16.50 21.70', 'CV173EGO': 'c000 0.70 17.70;c001 12.80 18.70;c004 1.20 22.71;c034 4.50 10.30;c044 0.80 12.9 ...

# %% [markdown]
# ### Functions for Extract Audio and Label the Clips

# %%
# Function to parse annotations
def parse_annotations(annotation_str, video_duration):
    actions = []
    last_end = 0

    # Check if annotation_str is a float and nan
    if isinstance(annotation_str, float) and math.isnan(annotation_str):
        # Handle the case where the annotation is nan
        return [{'action': 'no_action', 'start': 0, 'end': video_duration}]

    # Proceed if annotation_str is not nan
    for action in annotation_str.split(';'):
        parts = action.split()
        action_id = parts[0]
        start = round(float(parts[1]))
        end = round(float(parts[2]))

        # Check for gap between last action and current action
        if start > last_end:
            actions.append({'action': 'no_action', 'start': last_end, 'end': start})

        actions.append({'action': action_id, 'start': start, 'end': end})
        last_end = end

    # Check for action-less segment at the end of the video
    if last_end < video_duration:
        actions.append({'action': 'no_action', 'start': last_end, 'end': video_duration})

    return actions

def process_video(file_name, annotations, file_path):
    video = VideoFileClip(f"{file_path}/{file_name}.mp4")
    duration = int(video.duration)

    # Generate the action index map
    sorted_unique_actions = sorted(unique_actions_with_no_action)  # From your sorting code
    action_index_map = {action: idx for idx, action in enumerate(sorted_unique_actions)}

    mfcc_data = []
    spectrogram_data = []
    sample_rate = 16000

    for i in range(duration):
        audio_clip = video.subclip(i, i + 1).audio
        audio_clip_filename = f"audio_clip_{i}.wav"
        audio_clip.write_audiofile(audio_clip_filename, codec='pcm_s16le')
        audio_clip_input, sr = librosa.load(audio_clip_filename, sr=16000)
        os.remove(audio_clip_filename)  # Clean up audio files right away
        
        # Check for non-finite values
        if not np.isfinite(audio_clip_input).all():
            print(f"Non-finite values found in audio clip {i} of {file_name}, skipping this clip.")
            continue

        # Perform noise reduction
        try:
            audio_clip_input_reduced = nr.reduce_noise(y=audio_clip_input, sr=sr)
        except Exception as e:
            print(f"Error in noise reduction for clip {i} of {file_name}: {e}, skipping this clip.")
            continue

        # Check again for non-finite values after noise reduction
        if not np.isfinite(audio_clip_input_reduced).all():
            print(f"Non-finite values found after noise reduction in audio clip {i} of {file_name}, skipping this clip.")
            continue
        
        # Initialize binary action list for this second
        actions_this_second = [0] * len(sorted_unique_actions)

        # Populate the binary list based on actions occurring in this second
        for action in annotations:
            if i >= action['start'] and i < action['end']:
                action_idx = action_index_map[action['action']]
                actions_this_second[action_idx] = 1

        # Perform noise reduction and feature extraction
        audio_clip_input_reduced = nr.reduce_noise(y=audio_clip_input, sr=sample_rate)
        mfcc = librosa.feature.mfcc(y=audio_clip_input_reduced, sr=sample_rate)
        spect = librosa.amplitude_to_db(np.abs(librosa.stft(audio_clip_input_reduced)), ref=np.max)
        # Resizing operations
        # Adjust frequency dimension to 1024
        if spect.shape[0] > 1024:
            spect = spect[:1024, :]
        elif spect.shape[0] < 1024:
            padding_size = 1024 - spect.shape[0]
            spect = np.pad(spect, ((0, padding_size), (0, 0)))

        # Convert to tensor for resampling
        spect_tensor = torch.tensor(spect, dtype=torch.float32)

        # Add a channel dimension for interpolation
        spect_tensor = spect_tensor.unsqueeze(0).unsqueeze(0)  # Now [1, 1, 1024, Time]

        # Resample time dimension to 128
        spect_tensor = F.interpolate(spect_tensor, size=(1024, 128), mode='bilinear', align_corners=False)

        # Remove channel dimension
        spect = spect_tensor.squeeze(0).squeeze(0).numpy()
        # Append to data lists
        mfcc_data.append({
            'file_id': file_name,
            'sample_rate': sample_rate,
            'start_sec': i,
            'end_sec': i + 1,
            'mfcc': mfcc,
            'action': actions_this_second
        })

        spectrogram_data.append({
            'file_id': file_name,
            'sample_rate': sample_rate,
            'start_sec': i,
            'end_sec': i + 1,
            'spectrogram': spect,
            'action': actions_this_second
        })

    return mfcc_data, spectrogram_data

# %% [markdown]
# ### Processing

# %%
video_file_path = "/media/DiskDrive1/CharadesEgo"


# Main processing loop
all_mfcc_data = []
all_spectrogram_data = []

for file in video_files:
    video = VideoFileClip(f"{video_file_path}/{file}.mp4")
    parsed_anno = parse_annotations(annotations[file], int(video.duration))

    mfcc_data, spectrogram_data = process_video(file, parsed_anno, video_file_path)
    all_mfcc_data.extend(mfcc_data)
    all_spectrogram_data.extend(spectrogram_data)

# Convert to DataFrame and then to dictionaries
mfcc_dataset = pd.DataFrame(all_mfcc_data).to_dict('records')
spectrogram_dataset = pd.DataFrame(all_spectrogram_data).to_dict('records')

# Save the datasets
with open('mfcc_dataset_list.pkl', 'wb') as mfcc_file_list:
    pickle.dump(mfcc_dataset, mfcc_file_list)

with open('spectrogram_dataset_list.pkl', 'wb') as spectrogram_file_list:
    pickle.dump(spectrogram_dataset, spectrogram_file_list)

# Print dataset information
print(f"MFCC Dataset num_rows: {len(mfcc_dataset)}")
print(f"Spectrogram Dataset num_rows: {len(spectrogram_dataset)}")
# Out:
# MoviePy - Writing audio in audio_clip_0.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_1.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_2.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_3.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_4.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_5.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_6.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_7.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_8.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_9.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_10.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_11.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_12.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_13.wav
# MoviePy - Done.
# MoviePy - Writing audio in audio_clip_14.wav
# MoviePy - Done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 12
#       9 video = VideoFileClip(f"{video_file_path}/{file}.mp4")
#      10 parsed_anno = parse_annotations(annotations[file], int(video.duration))
# ---> 12 mfcc_data, spectrogram_data = process_video(file, parsed_anno, video_file_path)
#      13 all_mfcc_data.extend(mfcc_data)
#      14 all_spectrogram_data.extend(spectrogram_data)
#
# Cell In[11], line 44, in process_video(file_name, annotations, file_path)
#      41 sample_rate = 16000
#      43 for i in range(duration):
# ---> 44     audio_clip = video.subclip(i, i + 1).audio
#      45     audio_clip_filename = f"audio_clip_{i}.wav"
#      46     audio_clip.write_audiofile(audio_clip_filename, codec='pcm_s16le')
#
# File <decorator-gen-60>:2, in subclip(self, t_start, t_end)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File <decorator-gen-59>:2, in subclip(self, t_start, t_end)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/decorators.py:29, in apply_to_mask(f, clip, *a, **k)
#      24 @decorator.decorator
#      25 def apply_to_mask(f, clip, *a, **k):
#      26     """ This decorator will apply the same function f to the mask of
#      27         the clip created with f """
# ---> 29     newclip = f(clip, *a, **k)
#      30     if getattr(newclip, 'mask', None):
#      31         newclip.mask = f(newclip.mask, *a, **k)
#
# File <decorator-gen-58>:2, in subclip(self, t_start, t_end)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/decorators.py:41, in apply_to_audio(f, clip, *a, **k)
#      36 @decorator.decorator
#      37 def apply_to_audio(f, clip, *a, **k):
#      38     """ This decorator will apply the function f to the audio of
#      39         the clip created with f """
# ---> 41     newclip = f(clip, *a, **k)
#      42     if getattr(newclip, 'audio', None):
#      43         newclip.audio = f(newclip.audio, *a, **k)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:389, in Clip.subclip(self, t_start, t_end)
#     384 if (self.duration is not None) and (t_start > self.duration):
#     385     raise ValueError("t_start (%.02f) " % t_start +
#     386                      "should be smaller than the clip's " +
#     387                      "duration (%.02f)." % self.duration)
# --> 389 newclip = self.fl_time(lambda t: t + t_start, apply_to=[])
#     391 if (t_end is None) and (self.duration is not None):
#     393     t_end = self.duration
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:187, in Clip.fl_time(self, t_func, apply_to, keep_duration)
#     184 if apply_to is None:
#     185     apply_to = []
# --> 187 return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                keep_duration=keep_duration)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:136, in Clip.fl(self, fun, apply_to, keep_duration)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File <decorator-gen-85>:2, in set_make_frame(self, mf)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/decorators.py:14, in outplace(f, clip, *a, **k)
#      12 """ Applies f(clip.copy(), *a, **k) and returns clip.copy()"""
#      13 newclip = clip.copy()
# ---> 14 f(newclip, *a, **k)
#      15 return newclip
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/video/VideoClip.py:644, in VideoClip.set_make_frame(self, mf)
#     638 """Change the clip's ``get_frame``.
#     639
#     640 Returns a copy of the VideoClip instance, with the make_frame
#     641 attribute set to `mf`.
#     642 """
#     643 self.make_frame = mf
# --> 644 self.size = self.get_frame(0).shape[:2][::-1]
#
# File <decorator-gen-35>:2, in get_frame(self, t)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:136, in Clip.fl.<locals>.<lambda>(t)
#     133     apply_to = []
#     135 #mf = copy(self.make_frame)
# --> 136 newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     138 if not keep_duration:
#     139     newclip.duration = None
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:187, in Clip.fl_time.<locals>.<lambda>(gf, t)
#     184 if apply_to is None:
#     185     apply_to = []
# --> 187 return self.fl(lambda gf, t: gf(t_func(t)), apply_to,
#     188                keep_duration=keep_duration)
#
# File <decorator-gen-35>:2, in get_frame(self, t)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      85 new_a = [fun(arg) if (name in varnames) else arg
#      86          for (arg, name) in zip(a, names)]
#      87 new_kw = {k: fun(v) if k in varnames else v
#      88          for (k,v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/Clip.py:93, in Clip.get_frame(self, t)
#      91         return frame
#      92 else:
# ---> 93     return self.make_frame(t)
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/video/io/VideoFileClip.py:113, in VideoFileClip.__init__.<locals>.<lambda>(t)
#     109     self.mask.fps = self.fps
#     111 else:
# --> 113     self.make_frame = lambda t: self.reader.get_frame(t)
#     115 # Make a reader for the audio, if any.
#     116 if audio and self.reader.infos['audio_found']:
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:183, in FFMPEG_VideoReader.get_frame(self, t)
#     181     self.pos = pos
#     182 else:
# --> 183     self.skip_frames(pos-self.pos-1)
#     184 result = self.read_frame()
#     185 self.pos = pos
#
# File ~/anaconda3/lib/python3.11/site-packages/moviepy/video/io/ffmpeg_reader.py:111, in FFMPEG_VideoReader.skip_frames(self, n)
#     109 w, h = self.size
#     110 for i in range(n):
# --> 111     self.proc.stdout.read(self.depth*w*h)
#     112     #self.proc.stdout.flush()
#     113 self.pos += n
#
# KeyboardInterrupt:

# %%
print(spectrogram_dataset[:5])

# %% [markdown]
# ### Normalize

# %%
# Normalize MFCC dataset
for record in mfcc_dataset:
    record['mfcc'] = (record['mfcc'] - (-4.2677393)) / (4.5689974 * 2)

# Normalize Spectrogram dataset
for record in spectrogram_dataset:
    record['spectrogram'] = (record['spectrogram'] - (-4.2677393)) / (4.5689974 * 2)
    
# Save the datasets
with open('mfcc_dataset_list.pkl', 'wb') as mfcc_file_list:
    pickle.dump(mfcc_dataset, mfcc_file_list)

with open('spectrogram_dataset_list.pkl', 'wb') as spectrogram_file_list:
    pickle.dump(spectrogram_dataset, spectrogram_file_list)

# %%
import pickle

with open('spectrogram_dataset_list.pkl', 'rb') as file:
    spectrogram_dataset = pickle.load(file)

# %%
import gzip

# Compress data
def save_zipped_pickle_gz(obj, filename, protocol=-1):
    # Using gzip to compress the data
    with gzip.open(filename, 'wb') as f:
        pickle.dump(obj, f, protocol)

save_zipped_pickle_gz(spectrogram_dataset, 'spectrogram_dataset_list.pkl.gz')
